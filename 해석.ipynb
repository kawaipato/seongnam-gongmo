# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#한글설정
import matplotlib.pyplot as plt
from matplotlib import rc
# %matplotlib inline
rc('font', family='AppleGothic')

plt.rcParams['axes.unicode_minus'] = False
import warnings
warnings.filterwarnings(action='ignore')

# %%
df4 = pd.read_csv('kmeans_data_con4_2.csv',encoding='euc-kr')
df5 = pd.read_csv('kmeans_data_con5.csv',encoding='euc-kr')
df4_raw = df4.copy()
df5_raw = df5.copy()

# %%
df4.drop(columns='gid',inplace=True)
df5.drop(columns='gid',inplace=True)

# %%
df4_0 = df4[df4.label == 0]
df4_1 = df4[df4.label == 1]
df4_2 = df4[df4.label == 2]
df4_3 = df4[df4.label == 3]

# %%
df4_3.mean()
# Out:
# pa       0.544647
# ep       0.189236
# fp       0.202027
# yp       0.119157
# light    0.616824
# nb       0.303606
# label    3.000000
# dtype: float64

# %%
df4_3.mean()[1:4].sum()
# Out:
# 0.5104195548519601

# %%
#a_1 #x
data = pd.DataFrame(df4_0.mean()[:-1])
aa = ['경찰서접근성','노령인구', '여성인구','유소년인구','가로등','노후건물']
colors = ['black','dimgray','dimgrey','darkgray','silver','lightgrey']

plt.bar(aa, data[0],color=colors)
# plt.xlabel('Columns')
plt.show()

# %%
#a_1 #x
data = pd.DataFrame(df4_1.mean()[:-1])

plt.bar(data.index, data[0])
plt.xlabel('Columns')
plt.show()

# %%
#a_1 #x
plt.figure(figsize=(10,5))

data = pd.DataFrame(df4_2.mean()[:-1])
aa = ['경찰서접근성','노령인구', '여성인구','유소년인구','가로등','노후건물']
colors = ['black','dimgray','dimgrey','darkgray','silver','lightgrey']

plt.bar(aa, data[0], color=colors)
plt.title('2번 군집의 특성(평균)')
# plt.xlabel('features')
plt.ylabel('Standardized Mean')
plt.show()

# %%
#a_1 #x
data = pd.DataFrame(df4_3.mean()[:-1])

plt.bar(data.index, data[0])
plt.xlabel('Columns')
plt.show()

# %%
df5_0 = df5[df5.label == 0]
df5_1 = df5[df5.label == 1]
df5_2 = df5[df5.label == 2]
df5_3 = df5[df5.label == 3]
df5_4 = df5[df5.label == 4]

# %%
#a_1 #x
data = pd.DataFrame(df5_0.mean()[:-1])

plt.bar(data.index, data[0])
plt.xlabel('Columns')
plt.show()

# %%
#a_1 #x
data = pd.DataFrame(df5_1.mean()[:-1])

plt.bar(data.index, data[0])
plt.xlabel('Columns')
plt.show()

# %%
#a_1 #x
data = pd.DataFrame(df5_2.mean()[:-1])

plt.bar(data.index, data[0])
plt.xlabel('Columns')
plt.show()

# %%
#a_1 #x
data = pd.DataFrame(df5_3.mean()[:-1])

plt.bar(data.index, data[0])
plt.xlabel('Columns')
plt.show()

# %%
#a_1 #x
data = pd.DataFrame(df5_4.mean()[:-1])

plt.bar(data.index, data[0])
plt.xlabel('Columns')
plt.show()

# %%
df4_2['all'] = df4_2['ep'] + df4_2['fp'] + df4_2['yp']

# %%
df4_2['score']= (df4_2['all'] + df4_2['nb']) * 0.338 - (df4_2['pa'] + df4_2['light']) * 0.308

# %%
a = pd.read_csv('df_std.csv',encoding='euc-kr')
a
# Out:
#             pa        ep        fp        yp      cctv     light        nb  \
# 0     0.757896  0.238218  0.178516  0.000000  0.000000  0.592419  0.250172
# 1     0.749224  0.000000  0.000000  0.000000  0.000000  0.735251  0.250172
# 2     0.749224  0.000000  0.000000  0.000000  0.000000  0.655714  0.250172
# 3     0.749224  0.000000  0.000000  0.000000  0.000000  0.628545  0.320499
# 4     0.727538  0.000000  0.000000  0.000000  0.529358  0.539505  0.363463
# ...        ...       ...       ...       ...       ...       ...       ...
# 1076  0.506843  0.000000  0.000000  0.000000  0.000000  0.000000  0.250172
# 1077  0.506843  0.535203  0.527165  0.571053  0.651981  0.592419  0.320499
# 1078  0.469024  0.468444  0.408359  0.398223  0.000000  0.695243  0.542926
# 1079  0.441251  0.349199  0.340086  0.336884  0.770903  0.539505  0.419054
# 1080  0.441251  0.000000  0.000000  0.000000  0.000000  0.695243  0.000000
#
#              gid
# 0     ㅼ궗58ab30ba
# 1     ㅼ궗58bb30ab
# ...

# %%
df4_2['gid'] = a['gid']

# %%
df4_2.to_csv('fifinal.csv',encoding='euc-kr',index=False)
